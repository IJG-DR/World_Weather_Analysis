# %% [markdown]
# ## MODULE 6.5.4 - Map Vacation Criteria
#
# ### Practice Using a Fixed Latitude and Longitude

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEBNqSzPtM2Gqk-x4N5OSRL8bpIMC6jwlfqr_v7Tn1DtAVnAHx0SIN4RD_WTsme9Vn_Ss2AC9f0pRJVJeuEd49DXm7VfuwvbYr4AaEJN2vriFYjTcknnzscOAReXqrtLfCDRA48YzyggMucwu02O6griXgDIiAO-1hniISZx5AptkRYvzXmn8aLEuErOOvP1-1OwcqG3Fl3lIGc8AZAnk3DJjHRqRqQ7trfQHUlGuYRbt7cczfEwMi78vW0I_DL4jkcmvbB2Fp0583gnyLokDctrCFl3Vb1ADM-QdSxnZmWdFAYFAzkBF4IREh1fBD6wBbDMh82Fv-aKbmikS_jNCGUuCfkwR_Lzsykh77wcvWSiY2LU_TgeFGyfJJ7gtSAb75vONPtMlevjLjj206fy-J8z6GQxFbX8O0tK4vYevEHGnw6MlP2YrORe',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
# ...

# %%
# To get all the hotels in the results dictionary we can 
# get the length of this dictionary by using:
len(hotels["results"])
# Out:
# 20

# %%
# Retrieve the name of the first hotel in the JSON data
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'
